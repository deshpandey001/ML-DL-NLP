# %% [markdown]
# ## Wordnet Lemmatizer

# %%
# !pip install nltk
# Out:
# ...
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\varad deshpande\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\varad deshpande\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\varad deshpande\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\varad deshpande\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\varad deshpande\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\varad deshpande\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\varad deshpande\appdata\local\programs\python\python310\lib\site-packages)
# ...

# %%
import nltk
print(nltk.__file__)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 import nltk
#       2 print(nltk.__file__)
#
# File c:\Users\Varad Deshpande\AppData\Local\Programs\Python\Python310\lib\site-packages\nltk\__init__.py:180
#     177 else:
#     178     from nltk import cluster
# --> 180 from nltk.downloader import download, download_shell
#     182 try:
#     183     import tkinter
#
# File c:\Users\Varad Deshpande\AppData\Local\Programs\Python\Python310\lib\site-packages\nltk\downloader.py:2475
#    2465             pass
#    2468 ######################################################################
#    2469 # Main:
#    2470 ######################################################################
#    (...)
#    2473
#    2474 # Aliases
# -> 2475 _downloader = Downloader()
#    2476 download = _downloader.download
#    2479 def download_shell():
#
# ...

# %%
from nltk.stem import WordNetLemmatizer

lemmatizer=WordNetLemmatizer()

lemmatizer.lemmatize("going")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 5
#       1 from nltk.stem import WordNetLemmatizer
#       3 lemmatizer=WordNetLemmatizer()
# ----> 5 lemmatizer.lemmatize("going")
#
# File c:\Users\Varad Deshpande\AppData\Local\Programs\Python\Python310\lib\site-packages\nltk\stem\wordnet.py:85, in WordNetLemmatizer.lemmatize(self, word, pos)
#      60 def lemmatize(self, word: str, pos: str = "n") -> str:
#      61     """Lemmatize `word` by picking the shortest of the possible lemmas,
#      62     using the wordnet corpus reader's built-in _morphy function.
#      63     Returns the input word unchanged if it cannot be found in WordNet.
#    (...)
#      83     :return: The shortest lemma of `word`, for the given `pos`.
#      84     """
# ---> 85     lemmas = self._morphy(word, pos)
#      86     return min(lemmas, key=len) if lemmas else word
#
# ...
